# %%
import pandas as pd
import numpy as np

from matplotlib import pyplot as plt
import seaborn as sns
from pandas.plotting import autocorrelation_plot

# %%
ls

# %%
data_path = '../data/'

# %% [markdown]
# # ECL

# %%
ecl = pd.read_csv(data_path + 'ECL.csv', index_col=0)
ecl.index = pd.to_datetime(ecl.index)

# %%
print(ecl.shape)
ecl.head()
# Out:
# (26304, 321)
#                      MT_000  MT_001  MT_002  MT_003  MT_004  MT_005  MT_006  \
# date
# 2012-01-01 00:00:00    14.0    69.0   234.0   415.0   215.0  1056.0    29.0
# 2012-01-01 01:00:00    18.0    92.0   312.0   556.0   292.0  1363.0    29.0
# 2012-01-01 02:00:00    21.0    96.0   312.0   560.0   272.0  1240.0    29.0
# 2012-01-01 03:00:00    20.0    92.0   312.0   443.0   213.0   845.0    24.0
# 2012-01-01 04:00:00    22.0    91.0   312.0   346.0   190.0   647.0    16.0
#
#                      MT_007  MT_008  MT_009  ...  MT_311  MT_312   MT_313  \
# date                                         ...
# 2012-01-01 00:00:00   840.0   226.0   265.0  ...   676.0   372.0  80100.0
# 2012-01-01 01:00:00  1102.0   271.0   340.0  ...   805.0   452.0  95200.0
# 2012-01-01 02:00:00  1025.0   270.0   300.0  ...   817.0   430.0  96600.0
# 2012-01-01 03:00:00   833.0   179.0   211.0  ...   801.0   291.0  94500.0
# ...

# %% [markdown]
# #### 321 features, so let's check last 10:

# %%
for col in ecl.columns[-10:]:
    plt.figure(figsize=(20, 2))
    ecl[col].iloc[:500].plot()
    plt.title(col)
    plt.xlabel('')
    plt.show()

# %%
# plt.figure(figsize=(20, 10))
for col in ecl.columns.values[-10:]:
    autocorrelation_plot(ecl[col][500:700], label=col)
plt.legend(loc=(1.04, 0));

# %%
corr_ecl = ecl[ecl.columns.values[-10:]].corr()
corr_ecl.style.background_gradient(cmap='coolwarm')
# Out:
# <style type="text/css">
# #T_851b5_row0_col0, #T_851b5_row1_col1, #T_851b5_row2_col2, #T_851b5_row3_col3, #T_851b5_row4_col4, #T_851b5_row5_col5, #T_851b5_row6_col6, #T_851b5_row7_col7, #T_851b5_row8_col8, #T_851b5_row9_col9 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_851b5_row0_col1, #T_851b5_row0_col2 {
#   background-color: #e8765c;
#   color: #f1f1f1;
# }
# #T_851b5_row0_col3 {
#   background-color: #d85646;
#   color: #f1f1f1;
# }
# #T_851b5_row0_col4 {
#   background-color: #e97a5f;
#   color: #f1f1f1;
# }
# #T_851b5_row0_col5 {
#   background-color: #f08a6c;
#   color: #f1f1f1;
# }
# #T_851b5_row0_col6 {
#   background-color: #688aef;
#   color: #f1f1f1;
# }
# #T_851b5_row0_col7, #T_851b5_row7_col6 {
#   background-color: #7597f6;
#   color: #f1f1f1;
# }
# #T_851b5_row0_col8 {
#   background-color: #5673e0;
#   color: #f1f1f1;
# }
# #T_851b5_row0_col9 {
#   background-color: #adc9fd;
#   color: #000000;
# }
# #T_851b5_row1_col0 {
# ...

# %%
ecl['mov_avg'] = ecl.MT_320.rolling(24).mean()

plt.figure(figsize=(20, 2))
ecl['MT_320'].iloc[:1000].plot()
ecl['mov_avg'].iloc[:1000].plot(linewidth=5)
plt.title('MT_320')

plt.xlabel('')
plt.show()

# %% [markdown]
# # ETT

# %%
ett = pd.read_csv(data_path + 'ETTh1.csv', index_col=0)
ett.index = pd.to_datetime(ett.index)

# %%
print(ett.shape)
ett.head()
# Out:
# (17420, 7)
#                       HUFL   HULL   MUFL   MULL   LUFL   LULL         OT
# date
# 2016-07-01 00:00:00  5.827  2.009  1.599  0.462  4.203  1.340  30.531000
# 2016-07-01 01:00:00  5.693  2.076  1.492  0.426  4.142  1.371  27.787001
# 2016-07-01 02:00:00  5.157  1.741  1.279  0.355  3.777  1.218  27.787001
# 2016-07-01 03:00:00  5.090  1.942  1.279  0.391  3.807  1.279  25.044001
# 2016-07-01 04:00:00  5.358  1.942  1.492  0.462  3.868  1.279  21.948000

# %%
for col in ett.columns:
    plt.figure(figsize=(20, 2))
    ett[col].iloc[:500].plot()
    plt.title(col)
    plt.xlabel('')
    plt.show()

# %%
for col in ett.columns.values:
    autocorrelation_plot(ett[col][500:1500], label=col)
plt.legend(loc=(1.04, 0));

# %%
corr_ett = ett.corr()
corr_ett.style.background_gradient(cmap='coolwarm')
# Out:
# <style type="text/css">
# #T_a990e_row0_col0, #T_a990e_row1_col1, #T_a990e_row2_col2, #T_a990e_row3_col3, #T_a990e_row4_col4, #T_a990e_row5_col5, #T_a990e_row6_col6 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_a990e_row0_col1 {
#   background-color: #4961d2;
#   color: #f1f1f1;
# }
# #T_a990e_row0_col2, #T_a990e_row2_col0 {
#   background-color: #b8122a;
#   color: #f1f1f1;
# }
# #T_a990e_row0_col3 {
#   background-color: #4055c8;
#   color: #f1f1f1;
# }
# #T_a990e_row0_col4 {
#   background-color: #7a9df8;
#   color: #f1f1f1;
# }
# #T_a990e_row0_col5, #T_a990e_row2_col4 {
#   background-color: #4f69d9;
#   color: #f1f1f1;
# }
# #T_a990e_row0_col6, #T_a990e_row3_col4 {
#   background-color: #3d50c3;
#   color: #f1f1f1;
# }
# #T_a990e_row1_col0, #T_a990e_row6_col2 {
#   background-color: #5673e0;
#   color: #f1f1f1;
# }
# #T_a990e_row1_col2, #T_a990e_row3_col5 {
#   background-color: #5d7ce6;
#   color: #f1f1f1;
# }
# #T_a990e_row1_col3 {
# ...

# %%
ett['mov_avg'] = ett.OT.rolling(24).mean()

plt.figure(figsize=(20, 2))
ett['OT'].iloc[:1000].plot()
ett['mov_avg'].iloc[:1000].plot(linewidth=5)
plt.title('OT')

plt.xlabel('')
plt.show()

# %% [markdown]
# # WTH

# %%
wth = pd.read_csv(data_path + 'WTH.csv', index_col=0)
wth.index = pd.to_datetime(wth.index)

# %%
print(wth.shape)
wth.head()
# Out:
# (35064, 12)
#                      Visibility  DryBulbFarenheit  DryBulbCelsius  \
# date
# 2010-01-01 00:00:00        10.0                16              -9
# 2010-01-01 01:00:00        10.0                16              -9
# 2010-01-01 02:00:00        10.0                16              -9
# 2010-01-01 03:00:00        10.0                16              -9
# 2010-01-01 04:00:00        10.0                16              -9
#
#                      WetBulbFarenheit  DewPointFarenheit  DewPointCelsius  \
# date
# 2010-01-01 00:00:00                13                  7              -14
# 2010-01-01 01:00:00                13                  7              -14
# 2010-01-01 02:00:00                13                  7              -14
# 2010-01-01 03:00:00                13                  7              -14
# 2010-01-01 04:00:00                14                  9              -13
#
#                      RelativeHumidity  WindSpeed  WindDirection  \
# date
# ...

# %%
for col in wth.columns:
    plt.figure(figsize=(20, 2))
    wth[col].iloc[:500].plot()
    plt.title(col)
    plt.xlabel('')
    plt.show()

# %%
for col in wth.columns.values:
    autocorrelation_plot(wth[col][500:1500], label=col)
plt.legend(loc=(1.04, 0));

# %%
corr_wth = wth.corr()
corr_wth.style.background_gradient(cmap='coolwarm')
# Out:
# <style type="text/css">
# #T_dfeb2_row0_col0, #T_dfeb2_row1_col1, #T_dfeb2_row1_col2, #T_dfeb2_row2_col1, #T_dfeb2_row2_col2, #T_dfeb2_row3_col3, #T_dfeb2_row4_col4, #T_dfeb2_row5_col5, #T_dfeb2_row6_col6, #T_dfeb2_row7_col7, #T_dfeb2_row8_col8, #T_dfeb2_row9_col9, #T_dfeb2_row9_col10, #T_dfeb2_row10_col9, #T_dfeb2_row10_col10, #T_dfeb2_row11_col11 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_dfeb2_row0_col1, #T_dfeb2_row0_col2, #T_dfeb2_row4_col9, #T_dfeb2_row5_col10 {
#   background-color: #dedcdb;
#   color: #000000;
# }
# #T_dfeb2_row0_col3 {
#   background-color: #9fbfff;
#   color: #000000;
# }
# #T_dfeb2_row0_col4 {
#   background-color: #5d7ce6;
#   color: #f1f1f1;
# }
# #T_dfeb2_row0_col5 {
#   background-color: #5b7ae5;
#   color: #f1f1f1;
# }
# #T_dfeb2_row0_col6, #T_dfeb2_row8_col10 {
#   background-color: #4f69d9;
#   color: #f1f1f1;
# }
# #T_dfeb2_row0_col7, #T_dfeb2_row8_col11 {
#   background-color: #7093f3;
#   color: #f1f1f1;
# }
# ...

# %%
wth['mov_avg'] = wth.WetBulbCelsius.rolling(24).mean()

plt.figure(figsize=(20, 2))
wth['WetBulbCelsius'].iloc[:1000].plot()
wth['mov_avg'].iloc[:1000].plot(linewidth=5)
plt.title('WetBulbCelsius')

plt.xlabel('')
plt.show()
