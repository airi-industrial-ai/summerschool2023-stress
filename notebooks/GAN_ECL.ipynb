# %%
# !pip install git+https://github.com/airi-industrial-ai/ec23-tutorial -q
# Out:
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 722.8/722.8 kB 7.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 729.2/729.2 kB 15.5 MB/s eta 0:00:00
#   Building wheel for ectutorial (setup.py) ... done

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt
import torch
from torch.utils.data import DataLoader
from pytorch_lightning import Trainer
import requests

from ectutorial.data import SlidingWindowDataset, get_ecl_dataset
from ectutorial.gen_models import TCNGANModule
from ectutorial.plot import plot_pair_fake_val, plot_risk
from ectutorial.wcr import calculate_worst_case_risk

# %%
ecl = pd.read_csv('ECL.csv', index_col=0)
ecl.head()
# Out:
#                      MT_000  MT_001  MT_002  MT_003  MT_004  MT_005  MT_320
# date
# 2012-01-01 00:00:00    14.0    69.0   234.0   415.0   215.0  1056.0  2162.0
# 2012-01-01 01:00:00    18.0    92.0   312.0   556.0   292.0  1363.0  2835.0
# 2012-01-01 02:00:00    21.0    96.0   312.0   560.0   272.0  1240.0  2764.0
# 2012-01-01 03:00:00    20.0    92.0   312.0   443.0   213.0   845.0  2735.0
# 2012-01-01 04:00:00    22.0    91.0   312.0   346.0   190.0   647.0  2721.0

# %%
val_thresh = int(ecl.shape[0] * 0.7)
test_thresh = int(ecl.shape[0] * 0.85)

train_data = ecl.iloc[:val_thresh].copy()
val_data = ecl.iloc[val_thresh:test_thresh].copy()
test_data = ecl.iloc[test_thresh:].copy()

# %% [markdown]
# We apply a standard scaler for training stability.

# %%
scaler = StandardScaler()
val_data_norm = scaler.fit_transform(val_data)

# %%
window_size = 120
train_dataset = SlidingWindowDataset(val_data_norm, window_size=window_size, step_size=1)
train_loader = DataLoader(train_dataset, batch_size=64, shuffle=True, drop_last=True)
len(train_loader)
# Out:
# 38

# %%
next(iter(train_loader))[0]
# Out:
# tensor([[-5.8639e-01,  1.0613e+00, -2.7852e-01, -6.9688e-01, -6.4367e-02,
#          -2.9467e-01, -6.2324e-01],
#         [-4.7297e-01,  1.0224e+00, -2.7852e-01, -6.9688e-01,  7.5904e-01,
#           2.4602e-01, -1.7989e-01],
#         [-5.8639e-01,  1.1781e+00, -2.7852e-01, -6.7589e-01,  9.3805e-01,
#           4.4427e-01, -1.9997e-01],
#         [-9.2664e-01,  1.1781e+00, -2.7852e-01, -4.2492e-03,  5.9794e-01,
#           4.2625e-01,  1.6810e-01],
#         [-9.2664e-01,  7.8891e-01, -2.7852e-01,  3.9454e-01,  4.3684e-01,
#           1.0390e+00,  6.1146e-01],
#         [-8.5103e-01,  1.0545e-02, -2.7852e-01, -2.5238e-02, -1.7177e-01,
#           3.5415e-01,  7.0180e-01],
#         [-9.2664e-01, -1.0621e-01, -2.7852e-01, -8.2281e-01, -5.4767e-01,
#           3.9020e-01,  9.8621e-01],
#         [-8.5103e-01, -2.2297e-01, -2.7852e-01, -8.6479e-01,  6.5164e-01,
#          -1.1444e-01,  1.2455e+00],
#         [-8.5103e-01, -2.6188e-01, -2.7852e-01, -5.9193e-01,  1.1349e+00,
#          -3.3072e-01,  1.5985e+00],
#         [-6.2419e-01,  2.0514e-01, -2.7852e-01, -3.8205e-01,  1.7973e+00,
#          -3.4874e-01,  2.4100e+00],
#         [-5.8639e-01,  1.2949e+00, -2.7852e-01,  2.2663e-01,  2.1195e+00,
#           1.1716e-02,  2.1306e+00],
#         [-9.2664e-01,  4.3865e-01, -2.7852e-01,  3.7728e-02,  8.3064e-01,
#           1.0030e+00,  7.8378e-01],
#         [-7.7541e-01,  1.6622e-01,  1.2128e+00,  2.2663e-01,  1.0454e+00,
#           1.0390e+00,  1.2322e+00],
#         [-7.7541e-01,  1.6622e-01, -2.7852e-01,  3.4206e-01, -1.7177e-01,
#           5.5241e-01,  1.4881e+00],
#         [-9.2664e-01,  1.0545e-02, -2.7852e-01,  1.8465e-01,  2.3994e-01,
#           4.7762e-02,  1.8629e+00],
#         [-8.5103e-01,  1.2730e-01, -2.7852e-01, -4.6600e-01,  6.3374e-01,
#          -5.1095e-01,  1.5668e+00],
#         [-6.9980e-01,  1.0613e+00, -2.7852e-01,  5.8343e-01,  4.1894e-01,
#          -2.2258e-01,  1.2355e+00],
#         [-6.9980e-01,  1.5284e+00, -2.7852e-01,  4.0503e-01,  4.1894e-01,
#           8.4078e-01,  9.3602e-01],
#         [-5.4858e-01,  1.6062e+00, -2.7852e-01,  1.0557e+00,  2.5134e-02,
#           1.2914e+00,  6.4994e-01],
#         [-5.4858e-01,  1.3727e+00, -2.7852e-01,  1.2866e+00,  3.1154e-01,
#           1.6098e+00,  7.0013e-01],
#         [-5.4858e-01,  2.8297e-01, -2.7852e-01,  1.5909e+00,  1.9405e+00,
#           1.7720e+00,  9.7785e-01],
#         [-5.1077e-01,  1.2730e-01, -2.7852e-01,  1.6329e+00,  1.6183e+00,
#           1.2733e+00,  8.7412e-01],
#         [-5.8639e-01,  4.7757e-01, -2.7852e-01,  9.0876e-01,  1.6004e+00,
#           1.9195e-01,  4.6590e-01],
#         [-5.4858e-01, -7.2890e-01, -2.7852e-01,  1.8465e-01,  1.0633e+00,
#          -2.9467e-01,  2.6848e-01],
#         [-5.4858e-01, -1.4684e+00, -2.7852e-01, -4.2402e-01,  7.9484e-01,
#          -8.5339e-01, -1.4308e-01],
#         [-5.1077e-01, -1.2738e+00, -2.7852e-01, -3.4007e-01,  6.1584e-01,
#          -1.1658e+00, -3.3214e-01],
#         [-5.4858e-01, -1.4294e+00, -2.7852e-01, -6.3391e-01,  6.8744e-01,
#          -1.3160e+00, -4.4925e-01],
#         [-5.4858e-01, -1.3127e+00, -2.7852e-01, -9.6973e-01,  8.4854e-01,
#          -1.4421e+00, -6.9686e-01],
#         [-5.4858e-01, -1.8405e-01, -2.7852e-01, -1.8198e+00,  1.1464e-01,
#          -1.4602e+00, -1.0315e+00],
#         [-5.4858e-01,  3.6081e-01, -2.7852e-01, -1.0327e+00,  7.0534e-01,
#          -6.6715e-01, -9.8127e-01]])

# %%
for batch in train_loader:
    break
batch.shape
# Out:
# torch.Size([64, 120, 7])

# %%
gan = TCNGANModule(
    latent_dim=8,
    target_dim=len(ecl.columns),
    hidden_dim=64,
    num_layers=4,
    lr=0.0001,
)

# %%
trainer = Trainer(
    accelerator='auto',
    max_epochs=200,
    log_every_n_steps=10,
)

trainer.fit(
    model=gan,
    train_dataloaders=train_loader,
    val_dataloaders=train_loader,
)
# Out:
# INFO:pytorch_lightning.utilities.rank_zero:GPU available: True (cuda), used: True
# INFO:pytorch_lightning.utilities.rank_zero:TPU available: False, using: 0 TPU cores
# INFO:pytorch_lightning.utilities.rank_zero:IPU available: False, using: 0 IPUs
# INFO:pytorch_lightning.utilities.rank_zero:HPU available: False, using: 0 HPUs
# INFO:pytorch_lightning.accelerators.cuda:LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# INFO:pytorch_lightning.callbacks.model_summary:
#   | Name | Type      | Params
# -----------------------------------
# 0 | gen  | TCNModule | 52.6 K
# 1 | disc | TCNModule | 51.2 K
# -----------------------------------
# 103 K     Trainable params
# 0         Non-trainable params
# 103 K     Total params
# 0.415     Total estimated model params size (MB)
# Sanity Checking: 0it [00:00, ?it/s]
# /usr/local/lib/python3.10/dist-packages/pytorch_lightning/trainer/connectors/data_connector.py:480: PossibleUserWarning: Your `val_dataloader`'s sampler has shuffling enabled, it is strongly recommended that you turn shuffling off for val/test dataloaders.
#   rank_zero_warn(
# Training: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# INFO:pytorch_lightning.utilities.rank_zero:`Trainer.fit` stopped: `max_epochs=200` reached.

# %% [markdown]
# We load the pretrained model from a `checkpoint` file.

# %%
# url = 'https://raw.githubusercontent.com/airi-industrial-ai/ec23-tutorial/main/models/ver=6-epoch=0-step=76.ckpt'
# r = requests.get(url)
# open('ver=6-epoch=0-step=76.ckpt', 'wb').write(r.content);

# %%
# gan = TCNGANModule.load_from_checkpoint(
#     'ver=6-epoch=0-step=76.ckpt',
#     map_location='cpu',
#     latent_dim=8,
#     target_dim=len(ecl.columns),
#     hidden_dim=64,
#     num_layers=4,
#     lr=0.0001,
# )
# Out:
# C:\Users\danil\AppData\Local\Programs\Python\Python310\lib\site-packages\pytorch_lightning\utilities\migration\utils.py:49: PossibleUserWarning: The loaded checkpoint was produced with Lightning v2.0.3, which is newer than your current Lightning version: v2.0.0
#   rank_zero_warn(

# %% [markdown]
# Let us plot the pair plot to compare the fake and validation data. We can make fake data more "risky" by increasing the variance of the latent space using the temp parameter.
#
# As our generator is a convolutional network, we can create a sequnce of an arbitrary length, for example 1000.

# %%
torch.save(gan.state_dict(), 'gan_200_ECL_2')

# %%
seq_len = 504
torch.manual_seed(0)
fake = gan.sample(seq_len, temp=1)

plot_pair_fake_val(fake, val_data, scaler)

# %%
fake.shape
# Out:
# torch.Size([1000, 7])

# %%
from scipy.stats import ks_2samp

# scores = []
for (fake_feature, real_feature) in zip(range(7), val_data.columns):
    print(ks_2samp(scaler.inverse_transform(fake)[:, fake_feature], val_data.iloc[np.random.randint(len(val_data), size=seq_len)][real_feature].copy()))
# Out:
# KstestResult(statistic=0.3531746031746032, pvalue=2.6917745187605843e-28, statistic_location=10.980321100528705, statistic_sign=1)
# KstestResult(statistic=0.09126984126984126, pvalue=0.02998861906794667, statistic_location=152.86243441258017, statistic_sign=1)
# KstestResult(statistic=0.4523809523809524, pvalue=7.721047953113797e-47, statistic_location=7.9998121445169, statistic_sign=1)
# KstestResult(statistic=0.0873015873015873, pvalue=0.04288627365687868, statistic_location=525.9992717378526, statistic_sign=1)
# KstestResult(statistic=0.19047619047619047, pvalue=2.084171173915215e-08, statistic_location=187.97462290073076, statistic_sign=1)
# KstestResult(statistic=0.10714285714285714, pvalue=0.0061094487802190855, statistic_location=673.7424841356197, statistic_sign=1)
# KstestResult(statistic=0.35119047619047616, pvalue=5.614037375519017e-28, statistic_location=3546.8435739915203, statistic_sign=1)

# %%
from sklearn.metrics import mean_squared_error
from pandas.plotting import autocorrelation_plot
seq_len = 120

n = 100
fake_autocorr = np.zeros_like(fake)

for _ in range(n):

    sampl = pd.DataFrame(scaler.inverse_transform(gan.sample(seq_len, temp=1)))
    feature_autocorr = []
    for i in range(len(val_data.columns)):

        feature_autocorr.append(autocorrelation_plot(sampl[i]).lines[-1].get_ydata())
        # first = first + pd.DataFrame(scaler.inverse_transform(vae.sample()))

    fake_autocorr = fake_autocorr + np.array(feature_autocorr).reshape(120, 7)

fake_autocorr_means = fake_autocorr / n


mses = []
for i, name in enumerate(val_data.columns):
    mses.append(mean_squared_error(autocorrelation_plot(val_data[name].iloc[:120]).lines[-1].get_ydata(), fake_autocorr_means[:, i]))
    print(mses[i])

print()
print('all features mean: ', np.mean(mses))
# Out:
# 0.1155945089517438
# 0.05296872681037324
# 0.013692131504026765
# 0.04791686522378824
# 0.05299221961016368
# 0.061036174108008115
# 0.07342634636935577
#
# all features mean:  0.059660996082494235

# %%
from sklearn.metrics import mean_squared_error
from pandas.plotting import autocorrelation_plot
seq_len = 120

n = 100
fake_autocorr = np.zeros_like(gan.sample(seq_len, temp=1))

for _ in range(n):

    sampl = pd.DataFrame(scaler.inverse_transform(gan.sample(seq_len, temp=1)))
    feature_autocorr = []
    for i in range(len(val_data.columns)):

        feature_autocorr.append(autocorrelation_plot(sampl[i]).lines[-1].get_ydata())
        # first = first + pd.DataFrame(scaler.inverse_transform(vae.sample()))

    fake_autocorr = fake_autocorr + np.array(feature_autocorr).reshape(120, 7)

fake_autocorr_means = fake_autocorr / n


mses = []
for i, name in enumerate(val_data.columns):
    mses.append(mean_squared_error(autocorrelation_plot(val_data[name].iloc[:120]).lines[-1].get_ydata(), fake_autocorr_means[:, i]))
    print(mses[i])

print()
print('all features mean: ', np.mean(mses))
# Out:
# 0.11080409077217819
# 0.05883947056460053
# 0.013662076760946218
# 0.0559415900087075
# 0.0593362216040813
# 0.06424434733144442
# 0.07240403998491018
#
# all features mean:  0.06217597671812404

# %%
corr_ecl = val_data.corr() ######### тут весь вал
corr_ecl.style.background_gradient(cmap='coolwarm')
# Out:
# <style type="text/css">
# #T_a20b8_row0_col0, #T_a20b8_row1_col1, #T_a20b8_row2_col2, #T_a20b8_row3_col3, #T_a20b8_row4_col4, #T_a20b8_row5_col5, #T_a20b8_row6_col6 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_a20b8_row0_col1, #T_a20b8_row0_col2, #T_a20b8_row0_col3, #T_a20b8_row0_col4, #T_a20b8_row0_col5, #T_a20b8_row0_col6, #T_a20b8_row1_col0 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_a20b8_row1_col2 {
#   background-color: #6f92f3;
#   color: #f1f1f1;
# }
# #T_a20b8_row1_col3 {
#   background-color: #cad8ef;
#   color: #000000;
# }
# #T_a20b8_row1_col4 {
#   background-color: #8caffe;
#   color: #000000;
# }
# #T_a20b8_row1_col5 {
#   background-color: #ead4c8;
#   color: #000000;
# }
# #T_a20b8_row1_col6 {
#   background-color: #8db0fe;
#   color: #000000;
# }
# #T_a20b8_row2_col0 {
#   background-color: #516ddb;
#   color: #f1f1f1;
# }
# #T_a20b8_row2_col1 {
#   background-color: #85a8fc;
#   color: #f1f1f1;
# }
# #T_a20b8_row2_col3 {
#   background-color: #84a7fc;
#   color: #f1f1f1;
# }
# #T_a20b8_row2_col4 {
#   background-color: #536edd;
#   color: #f1f1f1;
# }
# #T_a20b8_row2_col5 {
#   background-color: #7295f4;
#   color: #f1f1f1;
# }
# #T_a20b8_row2_col6, #T_a20b8_row5_col0 {
#   background-color: #5875e1;
#   color: #f1f1f1;
# }
# #T_a20b8_row3_col0, #T_a20b8_row6_col2 {
#   background-color: #4a63d3;
#   color: #f1f1f1;
# }
# #T_a20b8_row3_col1 {
#   background-color: #d3dbe7;
#   color: #000000;
# }
# #T_a20b8_row3_col2 {
#   background-color: #7b9ff9;
#   color: #f1f1f1;
# }
# #T_a20b8_row3_col4 {
#   background-color: #f5c2aa;
#   color: #000000;
# }
# #T_a20b8_row3_col5 {
#   background-color: #f6a283;
#   color: #000000;
# }
# #T_a20b8_row3_col6 {
#   background-color: #c4d5f3;
#   color: #000000;
# }
# #T_a20b8_row4_col0, #T_a20b8_row4_col2 {
#   background-color: #5470de;
#   color: #f1f1f1;
# }
# #T_a20b8_row4_col1 {
#   background-color: #a2c1ff;
#   color: #000000;
# }
# #T_a20b8_row4_col3 {
#   background-color: #f6bfa6;
#   color: #000000;
# }
# #T_a20b8_row4_col5 {
#   background-color: #d9dce1;
#   color: #000000;
# }
# #T_a20b8_row4_col6 {
#   background-color: #e3d9d3;
#   color: #000000;
# }
# #T_a20b8_row5_col1 {
#   background-color: #f2cbb7;
#   color: #000000;
# }
# #T_a20b8_row5_col2 {
#   background-color: #779af7;
#   color: #f1f1f1;
# }
# #T_a20b8_row5_col3 {
#   background-color: #f59d7e;
#   color: #000000;
# }
# #T_a20b8_row5_col4 {
#   background-color: #dbdcde;
#   color: #000000;
# }
# #T_a20b8_row5_col6 {
#   background-color: #e0dbd8;
#   color: #000000;
# }
# #T_a20b8_row6_col0 {
#   background-color: #445acc;
#   color: #f1f1f1;
# }
# #T_a20b8_row6_col1 {
#   background-color: #96b7ff;
#   color: #000000;
# }
# #T_a20b8_row6_col3 {
#   background-color: #c0d4f5;
#   color: #000000;
# }
# #T_a20b8_row6_col4 {
#   background-color: #dddcdc;
#   color: #000000;
# }
# #T_a20b8_row6_col5 {
#   background-color: #d7dce3;
#   color: #000000;
# }
# </style>
# <table id="T_a20b8" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a20b8_level0_col0" class="col_heading level0 col0" >MT_000</th>
#       <th id="T_a20b8_level0_col1" class="col_heading level0 col1" >MT_001</th>
#       <th id="T_a20b8_level0_col2" class="col_heading level0 col2" >MT_002</th>
#       <th id="T_a20b8_level0_col3" class="col_heading level0 col3" >MT_003</th>
#       <th id="T_a20b8_level0_col4" class="col_heading level0 col4" >MT_004</th>
#       <th id="T_a20b8_level0_col5" class="col_heading level0 col5" >MT_005</th>
#       <th id="T_a20b8_level0_col6" class="col_heading level0 col6" >MT_320</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_
_row5_col5" class="data row5 col5" >1.000000</td>
#       <td id="T_a20b8_row5_col6" class="data row5 col6" >0.507850</td>
#     </tr>
#     <tr>
#       <th id="T_a20b8_level0_row6" class="row_heading level0 row6" >MT_320</th>
#       <td id="T_a20b8_row6_col0" class="data row6 col0" >-0.007997</td>
#       <td id="T_a20b8_row6_col1" class="data row6 col1" >0.245257</td>
#       <td id="T_a20b8_row6_col2" class="data row6 col2" >0.087659</td>
#       <td id="T_a20b8_row6_col3" class="data row6 col3" >0.406316</td>
#       <td id="T_a20b8_row6_col4" class="data row6 col4" >0.522881</td>
#       <td id="T_a20b8_row6_col5" class="data row6 col5" >0.507850</td>
#       <td id="T_a20b8_row6_col6" class="data row6 col6" >1.000000</td>
#     </tr>
#   </tbody>
# </table>

# %%
n = 100

first = pd.DataFrame(scaler.inverse_transform(gan.sample(seq_len, temp=1))).corr()
for _ in range(n-1):
    first = first + pd.DataFrame(scaler.inverse_transform(gan.sample(seq_len, temp=1))).corr()
corr_ecl_fake = first/ n
corr_ecl_fake.style.background_gradient(cmap='coolwarm')
# Out:
# <style type="text/css">
# #T_a9fc6_row0_col0, #T_a9fc6_row1_col1, #T_a9fc6_row2_col2, #T_a9fc6_row3_col3, #T_a9fc6_row4_col4, #T_a9fc6_row5_col5, #T_a9fc6_row6_col6 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_a9fc6_row0_col1, #T_a9fc6_row0_col3, #T_a9fc6_row0_col4, #T_a9fc6_row0_col5, #T_a9fc6_row1_col0, #T_a9fc6_row2_col6, #T_a9fc6_row5_col2 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_a9fc6_row0_col2 {
#   background-color: #5977e3;
#   color: #f1f1f1;
# }
# #T_a9fc6_row0_col6 {
#   background-color: #4257c9;
#   color: #f1f1f1;
# }
# #T_a9fc6_row1_col2 {
#   background-color: #4358cb;
#   color: #f1f1f1;
# }
# #T_a9fc6_row1_col3 {
#   background-color: #ead5c9;
#   color: #000000;
# }
# #T_a9fc6_row1_col4 {
#   background-color: #5b7ae5;
#   color: #f1f1f1;
# }
# #T_a9fc6_row1_col5 {
#   background-color: #f3c7b1;
#   color: #000000;
# }
# #T_a9fc6_row1_col6, #T_a9fc6_row2_col5 {
#   background-color: #6687ed;
#   color: #f1f1f1;
# }
# #T_a9fc6_row2_col0 {
#   background-color: #abc8fd;
#   color: #000000;
# }
# #T_a9fc6_row2_col1 {
#   background-color: #9abbff;
#   color: #000000;
# }
# #T_a9fc6_row2_col3 {
#   background-color: #8caffe;
#   color: #000000;
# }
# #T_a9fc6_row2_col4, #T_a9fc6_row6_col2 {
#   background-color: #4961d2;
#   color: #f1f1f1;
# }
# #T_a9fc6_row3_col0 {
#   background-color: #5f7fe8;
#   color: #f1f1f1;
# }
# #T_a9fc6_row3_col1 {
#   background-color: #f2c9b4;
#   color: #000000;
# }
# #T_a9fc6_row3_col2, #T_a9fc6_row4_col2 {
#   background-color: #5875e1;
#   color: #f1f1f1;
# }
# #T_a9fc6_row3_col4 {
#   background-color: #f7b093;
#   color: #000000;
# }
# #T_a9fc6_row3_col5 {
#   background-color: #de614d;
#   color: #f1f1f1;
# }
# #T_a9fc6_row3_col6, #T_a9fc6_row5_col6 {
#   background-color: #90b2fe;
#   color: #000000;
# }
# #T_a9fc6_row4_col0 {
#   background-color: #9fbfff;
#   color: #000000;
# }
# #T_a9fc6_row4_col1 {
#   background-color: #b9d0f9;
#   color: #000000;
# }
# #T_a9fc6_row4_col3 {
#   background-color: #f39778;
#   color: #000000;
# }
# #T_a9fc6_row4_col5, #T_a9fc6_row5_col1 {
#   background-color: #f7b599;
#   color: #000000;
# }
# #T_a9fc6_row4_col6 {
#   background-color: #6f92f3;
#   color: #f1f1f1;
# }
# #T_a9fc6_row5_col0 {
#   background-color: #688aef;
#   color: #f1f1f1;
# }
# #T_a9fc6_row5_col3 {
#   background-color: #dd5f4b;
#   color: #f1f1f1;
# }
# #T_a9fc6_row5_col4 {
#   background-color: #f2cab5;
#   color: #000000;
# }
# #T_a9fc6_row6_col0 {
#   background-color: #a5c3fe;
#   color: #000000;
# }
# #T_a9fc6_row6_col1 {
#   background-color: #bfd3f6;
#   color: #000000;
# }
# #T_a9fc6_row6_col3 {
#   background-color: #c4d5f3;
#   color: #000000;
# }
# #T_a9fc6_row6_col4 {
#   background-color: #6e90f2;
#   color: #f1f1f1;
# }
# #T_a9fc6_row6_col5 {
#   background-color: #bed2f6;
#   color: #000000;
# }
# </style>
# <table id="T_a9fc6" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a9fc6_level0_col0" class="col_heading level0 col0" >0</th>
#       <th id="T_a9fc6_level0_col1" class="col_heading level0 col1" >1</th>
#       <th id="T_a9fc6_level0_col2" class="col_heading level0 col2" >2</th>
#       <th id="T_a9fc6_level0_col3" class="col_heading level0 col3" >3</th>
#       <th id="T_a9fc6_level0_col4" class="col_heading level0 col4" >4</th>
#       <th id="T_a9fc6_level0_col5" class="col_heading level0 col5" >5</th>
#       <th id="T_a9fc6_level0_col6" class="col_heading level0 col6" >6</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a9fc6_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_a9fc6_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_a9fc6_row0_col1" class="data row0 col1" >-0.288154</td>
#       <td id="T_a9fc6_row0_col2" class="data row0 col2" >0.145769</td>
#       <td id="T_a9fc6_row0_col3" class="data row0 col3" >-0.135386</td>
#       <td id="T_a9fc6_row0_col4" class="data row0 col4" >0.103095</td>
#       <td id="T_a9fc6_row0_col5" class="data row0 col5" >-0.098068</td>
#       <td id="T_a9fc6_row0_col6" class="data row0 col6" >0.120369</td>
#     </tr>
#     <tr>
#       <th id="T_a9fc6_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_a9fc6_row1_col0" class="data row1 col0" >-0.288154</td>
#       <td id="T_a9fc6_row1_col1" class="data row1 col1" >1.000000</td>
#       <td id="T_a9fc6_row1_col2" class="data row1 col2" >0.080546</td>
#       <td id="T_a9fc6_row1_col3" class="data row1 col3" >0.491919</td>
#       <td id="T_a9fc6_row1_col4" class="data row1 col4" >0.198071</td>
#       <td id="T_a9fc6_row1_col5" class="data row1 col5" >0.578802</td>
#       <td id="T_a9fc6_row1_col6" class="data row1 col6" >0.223461</td>
#     </tr>
#     <tr>
#       <th id="T_a9fc6_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_a9fc6_row2_col0" class="data row2 col0" >0.145769</td>
#       <td id="T_a9fc6_row2_col1" class="data row2 col1" >0.080546</td>
#       <td id="T_a9fc6_row2_col2" class="data row2 col2" >1.000000</td>
#       <td id="T_a9fc6_row2_col3" class="data row2 col3" >0.144380</td>
#       <td id="T_a9fc6_row2_col4" class="data row2 col4" >0.145386</td>
#       <td id="T_a9fc6_row2_col5" class="data row2 col5" >0.053090</td>
#       <td id="T_a9fc6_row2_col6" class="data row2 col6" >0.097632</td>
#     </tr>
#     <tr>
#       <th id="T_a9fc6_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_a9fc6_row3_col0" class="data row3 col0" >-0.135386</td>
#       <td id="T_a9fc6_row3_col1" class="data row3 col1" >0.491919</td>
#       <td id="T_a9fc6_row3_col2" class="data row3 col2" >0.144380</td>
#       <td id="T_a9fc6_row3_col3" class="data row3 col3" >1.000000</td>
#       <td id="T_a9fc6_row3_col4" class="data row3 col4" >0.722637</td>
#       <td id="T_a9fc6_row3_col5" class="data row3 col5" >0.860006</td>
#       <td id="T_a9fc6_row3_col6" class="data row3 col6" >0.331341</td>
#     </tr>
#     <tr>
#       <th id="T_a9fc6_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_a9fc6_row4_col0" class="data row4 col0" >0.103095</td>
#       <td id="T_a9fc6_row4_col1" class="data row4 col1" >0.198071</td>
#       <td id="T_a9fc6_row4_col2" class="data row4 col2" >0.145386</td>
#       <td id="T_a9fc6_row4_col3" class="data row4 col3" >0.722637</td>
#       <td id="T_a9fc6_row4_col4" class="data row4 col4" >1.000000</td>
#       <td id="T_a9fc6_row4_col5" class="data row4 col5" >0.643861</td>
#       <td id="T_a9fc6_row4_col6" class="data row4 col6" >0.247821</td>
#     </tr>
#     <tr>
#       <th id="T_a9fc6_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_a9fc6_row5_col0" class="data row5 col0" >-0.098068</td>
#       <td id="T_a9fc6_row5_col1" class="data row5 col1" >0.578802</td>
#       <td id="T_a9fc6_row5_col2" class="data row5 col2" >0.053090</td>
#       <td id="T_a9fc6_row5_col3" class="data row5 col3" >0.860006</td>
#       <td id="T_a9fc6_row5_col4" class="data row5 col4" >0.643861</td>
#       <td id="T_a9fc6_row5_col5" class="data row5 col5" >1.000000</td>
#       <td id="T_a9fc6_row5_col6" class="data row5 col6" >0.332138</td>
#     </tr>
#     <tr>
#       <th id="T_a9fc6_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_a9fc6_row6_col0" class="data row6 col0" >0.120369</td>
#       <td id="T_a9fc6_row6_col1" class="data row6 col1" >0.223461</td>
#       <td id="T_a9fc6_row6_col2" class="data row6 col2" >0.097632</td>
#       <td id="T_a9fc6_row6_col3" class="data row6 col3" >0.331341</td>
#       <td id="T_a9fc6_row6_col4" class="data row6 col4" >0.247821</td>
#       <td id="T_a9fc6_row6_col5" class="data row6 col5" >0.332138</td>
#       <td id="T_a9fc6_row6_col6" class="data row6 col6" >1.000000</td>
#     </tr>
#   </tbody>
# </table>

# %%
mean_squared_error(corr_ecl_fake, corr_ecl)
# Out:
# 0.01415323010227232

# %%
from tqdm import tqdm

generated_val = []
for i in tqdm(range((len(val_data) - 120) * 2)):
    generated_val.append(scaler.inverse_transform(gan.sample(120)))
# Out:
# 100%|██████████| 4986/4986 [00:14<00:00, 352.31it/s]

# %%
np.save('gan_generated_ECL.npy', generated_val)

# %%
len(generated_val)
# Out:
# 4986
